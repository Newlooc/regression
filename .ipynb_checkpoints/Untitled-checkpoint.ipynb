# %%
import csv
import time
from collections import defaultdict
import sys

start = 1388505600

f = open("data/train.csv")
readers = csv.reader(f)

keys = ('AMB_TEMP', 'CH4', 'CO', 'NMHC', 'NO', 'NO2', 'NOx', 'O3', 'PM10', 'PM2.5', 'RAINFALL', 'RH', 'SO2', 'THC', 'WD_HR', 'WIND_DIREC', 'WIND_SPEED', 'WS_HR')
writeList = ('PM2.5')

dayOfContent = defaultdict(dict)

for rkey, row in enumerate(readers) :
    if(rkey > 0) :
        for cKey, column in enumerate(row) :
            if(cKey > 1) :
                timeString = '{} {}'.format(row[0], str(cKey - 2))
                ts = time.strptime(timeString, '%Y/%m/%d %H')
                tsKey = time.mktime(ts)
                if row[1] in writeList :
                    dayOfContent[(int(tsKey) - start) / 3600][row[1]] = column

                
print(dayOfContent)
#fx = w1 * x**3 + w2 * x**2 + w3 * x + b

w1 = w2 = w3 = b = 1
gradW1 = gradW2 = gradW3 = gradB = 0
lr = 0.00001
loop = 100000

for l in range(loop) :
    for time in dayOfContent :
        data = dayOfContent[time]['PM2.5']
        print(time)
        sys.exit()
        #gradW1 += -2 * (data - time**3 * W1)
# Out:
# defaultdict(<type 'dict'>, {0: {'PM2.5': '26'}, 1: {'PM2.5': '39'}, 2: {'PM2.5': '36'}, 3: {'PM2.5': '35'}, 4: {'PM2.5': '31'}, 5: {'PM2.5': '28'}, 6: {'PM2.5': '25'}, 7: {'PM2.5': '20'}, 8: {'PM2.5': '19'}, 9: {'PM2.5': '30'}, 10: {'PM2.5': '41'}, 11: {'PM2.5': '44'}, 12: {'PM2.5': '33'}, 13: {'PM2.5': '37'}, 14: {'PM2.5': '36'}, 15: {'PM2.5': '45'}, 16: {'PM2.5': '42'}, 17: {'PM2.5': '49'}, 18: {'PM2.5': '45'}, 19: {'PM2.5': '44'}, 20: {'PM2.5': '41'}, 21: {'PM2.5': '30'}, 22: {'PM2.5': '24'}, 23: {'PM2.5': '13'}, 24: {'PM2.5': '21'}, 25: {'PM2.5': '23'}, 26: {'PM2.5': '30'}, 27: {'PM2.5': '30'}, 28: {'PM2.5': '22'}, 29: {'PM2.5': '18'}, 30: {'PM2.5': '13'}, 31: {'PM2.5': '13'}, 32: {'PM2.5': '11'}, 33: {'PM2.5': '22'}, 34: {'PM2.5': '25'}, 35: {'PM2.5': '34'}, 36: {'PM2.5': '38'}, 37: {'PM2.5': '50'}, 38: {'PM2.5': '53'}, 39: {'PM2.5': '43'}, 40: {'PM2.5': '43'}, 41: {'PM2.5': '45'}, 42: {'PM2.5': '46'}, 43: {'PM2.5': '32'}, 44: {'PM2.5': '16'}, 45: {'PM2.5': '19'}, 46: {'PM2.5': '22'}, 47: {'PM2.5': '26'}, 48: {'PM2.5': '19'}, 49: {'PM2.5': '25'}, 50: {'PM2.5': '27'}, 51: {'PM2.5': '20'}, 52: {'PM2.5': '16'}, 53: {'PM2.5': '14'}, 54: {'PM2.5': '15'}, 55: {'PM2.5': '8'}, 56: {'PM2.5': '4'}, 57: {'PM2.5': '9'}, 58: {'PM2.5': '16'}, 59: {'PM2.5': '22'}, 60: {'PM2.5': '23'}, 61: {'PM2.5': '29'}, 62: {'PM2.5': '32'}, 63: {'PM2.5': '36'}, 64: {'PM2.5': '34'}, 65: {'PM2.5': '45'}, 66: {'PM2.5': '40'}, 67: {'PM2.5': '41'}, 68: {'PM2.5': '23'}, 69: {'PM2.5': '29'}, 70: {'PM2.5': '23'}, 71: {'PM2.5': '37'}, 72: {'PM2.5': '27'}, 73: {'PM2.5': '27'}, 74: {'PM2.5': '14'}, 75: {'PM2.5': '20'}, 76: {'PM2.5': '22'}, 77: {'PM2.5': '24'}, 78: {'PM2.5': '26'}, 79: {'PM2.5': '33'}, 80: {'PM2.5': '48'}, 81: {'PM2.5': '50'}, 82: {'PM2.5': '49'}, 83: {'PM2.5': '45'}, 84: {'PM2.5': '63'}, 85: {'PM2.5': '63'}, 86: {'PM2.5': '62'}, 87: {'PM2.5': '55'}, 88: {'PM2.5': '56'}, 89: {'PM2.5': '67'}, 90: {'PM2.5': '78'}, 91: {'PM2.5': '83'}, 92: {'PM2.5': '90'}, 93: {'PM2.5': '75'}, 94: {'PM2.5': '85'}, 95: {'PM2.5': '82'}, 96: {'PM2.5': '80'}, 97: {'PM2.5': '80'}, 98: {'PM2.5': '76'}, 99: {'PM2.5': '81'}, 100: {'PM2.5': '75'}, 101: {'PM2.5': '66'}, 102: {'PM2.5': '70'}, 103: {'PM2.5': '65'}, 104: {'PM2.5': '66'}, 105: {'PM2.5': '57'}, 106: {'PM2.5': '56'}, 107: {'PM2.5': '64'}, 108: {'PM2.5': '67'}, 109: {'PM2.5': '72'}, 110: {'PM2.5': '64'}, 111: {'PM2.5': '73'}, 112: {'PM2.5': '57'}, 113: {'PM2.5': '57'}, 114: {'PM2.5': '53'}, 115: {'PM2.5': '70'}, 116: {'PM2.5': '70'}, 117: {'PM2.5': '60'}, 118: {'PM2.5': '68'}, 119: {'PM2.5': '66'}, 120: {'PM2.5': '66'}, 121: {'PM2.5': '55'}, 122: {'PM2.5': '46'}, 123: {'PM2.5': '46'}, 124: {'PM2.5': '46'}, 125: {'PM2.5': '42'}, 126: {'PM2.5': '35'}, 127: {'PM2.5': '35'}, 128: {'PM2.5': '40'}, 129: {'PM2.5': '45'}, 130: {'PM2.5': '48'}, 131: {'PM2.5': '57'}, 132: {'PM2.5': '57'}, 133: {'PM2.5': '59'}, 134: {'PM2.5': '62'}, 135: {'PM2.5': '59'}, 136: {'PM2.5': '61'}, 137: {'PM2.5': '50'}, 138: {'PM2.5': '60'}, 139: {'PM2.5': '62'}, 140: {'PM2.5': '62'}, 141: {'PM2.5': '50'}, 142: {'PM2.5': '45'}, 143: {'PM2.5': '43'}, 144: {'PM2.5': '41'}, 145: {'PM2.5': '32'}, 146: {'PM2.5': '35'}, 147: {'PM2.5': '31'}, 148: {'PM2.5': '33'}, 149: {'PM2.5': '25'}, 150: {'PM2.5': '36'}, 151: {'PM2.5': '28'}, 152: {'PM2.5': '33'}, 153: {'PM2.5': '29'}, 154: {'PM2.5': '42'}, 155: {'PM2.5': '56'}, 156: {'PM2.5': '66'}, 157: {'PM2.5': '78'}, 158: {'PM2.5': '62'}, 159: {'PM2.5': '61'}, 160: {'PM2.5': '47'}, 161: {'PM2.5': '54'}, 162: {'PM2.5': '57'}, 163: {'PM2.5': '59'}, 164: {'PM2.5': '61'}, 165: {'PM2.5': '43'}, 166: {'PM2.5': '39'}, 167: {'PM2.5': '38'}, 168: {'PM2.5': '48'}, 169: {'PM2.5': '53'}, 170: {'PM2.5': '60'}, 171: {'PM2.5': '60'}, 172: {'PM2.5': '52'}, 173: {'PM2.5': '47'}, 174: {'PM2.5': '45'}, 175: {'PM2.5': '50'}, 176: {'PM2.5': '43'}, 177: {'PM2.5': '40'}, 178: {'PM2.5': '42'}, 179: {'PM2.5': '41'}, 180: {'PM2.5': '39'}, 181: {'PM2.5': '36'}, 182: {'PM2.5': '35'}, 183: {'PM2.5': '36'}, 184: {'PM2.5': '36'}, 185: {'PM2.5':  ...
# 0
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
# Out:
# 7200
